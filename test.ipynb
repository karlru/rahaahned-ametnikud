# %%
import pandas as pd

# %%
data_excel = pd.read_excel(
    "data/ametnike_palgad_2018.xlsx", 
    sheet_name=3, 
    header=6, 
    skiprows=[7]
)
data_excel
# Out:
#                                Asutus           Struktuuriüksus  \
# 0            Andmekaitse Inspektsioon  Andmekaitse Inspektsioon
# 1            Andmekaitse Inspektsioon  Andmekaitse Inspektsioon
# 2            Andmekaitse Inspektsioon  Andmekaitse Inspektsioon
# 3            Andmekaitse Inspektsioon  Andmekaitse Inspektsioon
# 4            Andmekaitse Inspektsioon  Andmekaitse Inspektsioon
# ...                               ...                       ...
# 13157  Vabariigi Presidendi Kantselei                       NaN
# 13158  Vabariigi Presidendi Kantselei              Välisosakond
# 13159  Vabariigi Presidendi Kantselei               Siseosakond
# 13160  Vabariigi Presidendi Kantselei               Siseosakond
# 13161  Vabariigi Presidendi Kantselei                       NaN
#
#                      Ametikoht  Eesnimi Perekonnanimi  \
# 0                  Peadirektor   Viljar          Peep
# 1                õigusdirektor    Raavo          Palu
# ...

# %%
data_csv = pd.read_csv(
    'data/keskmine_brutopalk.csv',
    header=1
)
data_csv
# Out:
#                             Näitaja  \
# 0      Keskmine brutokuupalk, eurot
# 1      Keskmine brutokuupalk, eurot
# 2      Keskmine brutokuupalk, eurot
# 3      Keskmine brutokuupalk, eurot
# 4      Keskmine brutokuupalk, eurot
# ..                              ...
# 475  Brutopalga kogusumma jaotus, %
# 476  Brutopalga kogusumma jaotus, %
# 477  Brutopalga kogusumma jaotus, %
# 478  Brutopalga kogusumma jaotus, %
# 479  Brutopalga kogusumma jaotus, %
#
#                                             Tegevusala  2018  2018 I kvartal  \
# 0                             Kokku – kõik tegevusalad  1310          1242.0
# 1             Põllumajandus, metsamajandus ja kalapüük  1163          1133.0
# 2                                           Mäetööstus  1606          1547.0
# 3                                      Töötlev tööstus  1249          1189.0
# 4    Elektrienergia, gaasi, auru ja konditsioneerit...  1857          2101.0
# ...
